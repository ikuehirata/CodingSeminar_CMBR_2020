# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Lesson 4 - Exercise 1
#
# Here is a dataset of iris flowers [iris.csv](https://github.com/pandas-dev/pandas/blob/master/pandas/tests/data/iris.csv) and some iris flowers which species names are unknown. Identify the species name of each flowers below.
#
# | Name  | SepalLength | SepalWidth | PetalLength | PetalWidth |
# |-------|-------------|------------|-------------|------------|
# | iris1 | 6.5         | 3          | 5           | 1.2        |
# | iris2 | 6.5         | 3          | 5           | 2.4        |
# | iris3 | 6           | 3          | 2           | 0.5        |
#
# Hint:
# 1. Import `iris.csv` to a `pandas.DataFrame`.
# 2. Add the unknown flowers data to the `DataFrame`.
# 3. Plot each parameters by `seaborn.pairplot` to show the characteristics of the species.

# %% [markdown]
# What we are going to do is a pattern matching. Therefore this is, so to say, human-fource machine learning.
# First, let's see how the original (teacher) data seem like.

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
df = pd.read_csv("iris.csv")
sns.pairplot(df, hue="Name")

# %% [markdown]
# Add the unknown iris to the dataframe. To see the unknown flowers better, I changed the markers.

# %%
df2 = pd.DataFrame({
    "Name": ["iris1", "iris2", "iris3"],
    "SepalLength": [6.5, 6.5, 6],
    "SepalWidth": [3, 3, 3],
    "PetalLength": [5, 5, 2],
    "PetalWidth": [1.2, 2.4, 0.5]})
df = df.append(df2, sort=False)
sns.pairplot(df, hue="Name",
    markers=['.', '.', '.', "x", "x", "x"])
# Out:
# C:\Users\Ikue\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Ikue\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# From the result above, we can guess:
# - iris1 = Iris-versicolor
# - iris2 = Iris-virginica
# - iris3 = Iris-setosa
